# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafikzn/MyProject/blob/main/TD2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TD2 - Multidisciplinary Analysis

# %% [markdown]
# **First name:** <font color="Green">*Rafi*</font>
#
# **Last name:** <font color="Green">*Kouzouyan*</font>

# %% [markdown]
# ## Instructions
#
# In this session, we are implementing several numerical methods for multidisciplinary analysis.
#
# Do not hesitate to read the course and ask questions!
#
# This notebook will help you to prepare your report. **This notebook (or a PDF export of this notebook) is not your report!**</font>
#
# <span style="color:blue">***To return your work: send this notebook and **a report (PDF)** in which you will analyze the results obtained for each question at [loic.brevault@onera.fr](mailto:loic.brevault@onera.fr) before the November, 17th at noon. A special care is required with respect to the presentation of your approach and the analysis of the results. Elaborate clearly your reasoning.***</span>
#
# <font color="red">⚠️ **WARNING: penalty of -1pt per hour of delay** ⚠️</font>

# %% [markdown]
# ## Code and questions

# %%
# Install the package (the "!" character is required for google colab)
# !pip install geneticalgorithm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for func-timeout: filename=func_timeout-4.3.5-py3-none-any.whl size=15077 sha256=af8130ff175dddac9c598fc0e16c53bb86d257d6fc1e1cd6af149a44721d8e88
#   Stored in directory: /root/.cache/pip/wheels/ed/94/4a/9ccd71f7284a92e4137b7dd0ce8540c40ea7c2689251504a49
# Successfully built func-timeout
# ...

# %%
# Import science
from scipy import optimize
from scipy.optimize import fsolve
import numpy as np

# Import d'un algorithme générique
from geneticalgorithm import geneticalgorithm as ga

# Import plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# %% [markdown]
# ### 1 - Definition of disciplines

# %% [markdown]
# Here are 4 functions representing the disciplines of a MDAO problem. The objective of this work is to code each function and to solve the multidisciplinary system of equations.

# %% [markdown]
# #### <font color="steelblue">Discipline 1</font>
#
# \begin{align*}
# y_1 (z_1,z_2,z_3 )= (z_1-0.3)^2 \times (z_3-1.5)-0.5 \times \cos(2.0 \times z_2^3)
# \end{align*}
#
# #### <font color="steelblue">Discipline 2</font>
#
# \begin{align*}
# y_2 (z_1,z_2,y_1,y_4 )= \left[ \sin(1.4 \times y_4 \times z_2) + 0.5 \times z_1 \times y_1 \right]^2
# \end{align*}
#
# #### <font color="steelblue">Discipline 3</font>
#
# \begin{align*}
# y_3(z_2, y_2) = 1.3 \times z_2 \times y_2^{\frac{1}{3}}
# \end{align*}
#
# #### <font color="steelblue">Discipline 4</font>
#
# \begin{align*}
# y_4 (z_1, y_1, y_2, y_3,x)= 0.3 \times \cos(z_1 \times y_3 - y_1 \times y_2) + 0.3 \times \cos(x)^2
# \end{align*}
#
# #### <font color="steelblue">State equation R4</font>
#
# \begin{align*}
# R_4 (z_1, y_2, x)= 0.2 \times \sqrt{\exp(x)\times y_2} - (1.32-y_2)\times x^3 \times z_1 = 0
# \end{align*}
#
# #### <font color="steelblue">Additional information: </font>
#
# \begin{align*}
# z_1 = 0.6 \\
# z_2 = 0.5 \\
# z_3 = 0.4
# \end{align*}

# %% [markdown]
# ***Q1: For each discipline, identify the <span style="color:steelblue">design</span>, <span style="color:steelblue">coupling</span> and <span style="color:steelblue">state</span> variables***.

# %% [markdown]
# In Discipline 1 the design variable are z1, z2 and z3, the coupling variable is y1 and it does't have state variable.
#
# In Discipline 2 the design variable are z1 and z2, the coupling variable are y1, y2 and y4 and it also does't have state variable.
#
# In Discipline 3 the design variable is z2, the coupling variable are y3 and y2 and it does't have state variable.
#
# In Discipline 4 the design variable is z1, the coupling variable are y1, y2 and y3 and the state variable is x.

# %% [markdown]
# ***Q2: Make the N2 chart of the system: which types of couplings are involved (<span style="color:steelblue">feedback</span>, <span style="color:steelblue">feedforward</span>), which types of interaction (<span style="color:steelblue">sequential</span>, <span style="color:steelblue">parallel</span>, <span style="color:steelblue">coupled</span>)?***

# %% [markdown]
# ***Q3: Code the 4 disciplines and validate your results. For the state equation, you don't need to solve it yet, just code the equation itself (see Q4).***

# %% [markdown]
# ***Q4: Code the numerical solving of the equation $R_4(\cdot,\cdot,\cdot) = 0$ (use the function `scipy.optimize.fsolve` from the package `scipy`) to solve the equation. Indicate what is the value of $x$ for $y_2 = 1$***.
#
# See the `scipy` [documentation](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.fsolve.html#scipy-optimize-fsolve)

# %% [markdown]
# ### 2 - MultiDisciplinary Analysis (MDA)

# %% [markdown]
# ***Q5: Perform a multidisciplinary analysis (MDA) with a fixed point iteration method. Print the value of the coupling variables at each iteration.***

# %% [markdown]
# ***Q6: Perform the MDA with optimization algorithms, first with a genetic algorithm, then with Nelder-Mead. Describe the process, the variables, the algorithm and the objective function.***

# %% [markdown]
# With a [genetic algorithm](https://pypi.org/project/geneticalgorithm/):

# %% [markdown]
# With the [Nelder-Mead algorithm](https://docs.scipy.org/doc/scipy/reference/optimize.minimize-neldermead.html#optimize-minimize-neldermead):

# %% [markdown]
# ***Q7: Plot the convergence curve of the MDA with both algorithms***

# %% [markdown]
# ***Q8: Are there multiple values of coupling variables that satisfy the multidisciplinary system? How can you show it (assuming unlimited computational budget, that is, you can run the disciplines many times)? Code what you propose.***
